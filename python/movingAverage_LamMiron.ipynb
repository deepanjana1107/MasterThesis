# %%
import numpy as np 
import pandas as pd

# %%
df5 = pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/VPBirth.csv', sep=";")

# %%
df5
# Out:
#      Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0    1758   13   15   14    5    5    5    2    4    7   13    9   11
# 1    1759   11   10    7    4    3    6   11    5   11   15   10   13
# 2    1760   19   15   18    5   13    6   10    9   13   14    8   13
# 3    1761   14   16   14    9    9   11   10   10   12   14   15   20
# 4    1762   13   12   12    8    5    3    8   10    6   10   10    9
# 5    1763    8   19   12    4   11   10    7   12   16   16   16    9
# 6    1764   16   13   16    8    7    3    2    6   10   10   13   19
# 7    1765   13   18    9   15    8    5    4   10   15   16   15   16
# 8    1766   13   20   17    7    5    5    7   11   12    9    8    9
# 9    1767   13    4    9    7    4    5    8    7   17   18   19   17
# 10   1768   15    5   10   14    5    6    8    8    8   13    9   16
# 11   1769   10   13   11    7    6    7    9   10    9   17   11   19
# ...

# %%
df5[['Year']] = df5[['Year']].astype(str)

# %%
df5.dtypes
# Out:
# Year    object
# Jan      int64
# Feb      int64
# Mar      int64
# Apr      int64
# May      int64
# Jun      int64
# Jul      int64
# Aug      int64
# Sep      int64
# Oct      int64
# Nov      int64
# Dec      int64
# dtype: object

# %%
df5 = df5.set_index('Year')

# %%
df5
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 1758   13   15   14    5    5    5    2    4    7   13    9   11
# 1759   11   10    7    4    3    6   11    5   11   15   10   13
# 1760   19   15   18    5   13    6   10    9   13   14    8   13
# 1761   14   16   14    9    9   11   10   10   12   14   15   20
# 1762   13   12   12    8    5    3    8   10    6   10   10    9
# 1763    8   19   12    4   11   10    7   12   16   16   16    9
# 1764   16   13   16    8    7    3    2    6   10   10   13   19
# 1765   13   18    9   15    8    5    4   10   15   16   15   16
# 1766   13   20   17    7    5    5    7   11   12    9    8    9
# 1767   13    4    9    7    4    5    8    7   17   18   19   17
# 1768   15    5   10   14    5    6    8    8    8   13    9   16
# 1769   10   13   11    7    6    7    9   10    9   17   11   19
# 1770   12    8   17    9    4    9    9   14   15    9   13   22
# ...

# %%
df5.transpose()
# Out:
# Year  1758  1759  1760  1761  1762  1763  1764  1765  1766  1767  ...   1891  \
# Jan     13    11    19    14    13     8    16    13    13    13  ...      8
# Feb     15    10    15    16    12    19    13    18    20     4  ...      8
# Mar     14     7    18    14    12    12    16     9    17     9  ...      5
# Apr      5     4     5     9     8     4     8    15     7     7  ...      4
# May      5     3    13     9     5    11     7     8     5     4  ...      2
# Jun      5     6     6    11     3    10     3     5     5     5  ...      7
# Jul      2    11    10    10     8     7     2     4     7     8  ...      8
# Aug      4     5     9    10    10    12     6    10    11     7  ...      9
# Sep      7    11    13    12     6    16    10    15    12    17  ...     17
# Oct     13    15    14    14    10    16    10    16     9    18  ...     17
# Nov      9    10     8    15    10    16    13    15     8    19  ...     10
# ...

# %%
df5 = df5.transpose()

# %%
df5
# Out:
# Year  1758  1759  1760  1761  1762  1763  1764  1765  1766  1767  ...   1891  \
# Jan     13    11    19    14    13     8    16    13    13    13  ...      8
# Feb     15    10    15    16    12    19    13    18    20     4  ...      8
# Mar     14     7    18    14    12    12    16     9    17     9  ...      5
# Apr      5     4     5     9     8     4     8    15     7     7  ...      4
# May      5     3    13     9     5    11     7     8     5     4  ...      2
# Jun      5     6     6    11     3    10     3     5     5     5  ...      7
# Jul      2    11    10    10     8     7     2     4     7     8  ...      8
# Aug      4     5     9    10    10    12     6    10    11     7  ...      9
# Sep      7    11    13    12     6    16    10    15    12    17  ...     17
# Oct     13    15    14    14    10    16    10    16     9    18  ...     17
# Nov      9    10     8    15    10    16    13    15     8    19  ...     10
# ...

# %%
result = df5.stack()

# %%
result
# Out:
#      Year
# Jan  1758    13
#      1759    11
#      1760    19
#      1761    14
#      1762    13
#      1763     8
#      1764    16
#      1765    13
#      1766    13
#      1767    13
#      1768    15
#      1769    10
#      1770    12
#      1771    18
#      1772     9
#      1773    18
#      1774    22
#      1775    17
#      1776    13
#      1777    31
#      1778    16
#      1779    18
#      1780    20
#      1781    16
#      1782    23
#      1783    19
#      1784    16
#      1785    13
#      1786    10
#      1787    23
#              ..
# Dec  1871    15
#      1872    11
#      1873    15
#      1874    11
#      1875    14
#      1876    10
#      1877    10
#      1878     8
#      1879    12
#      1880    11
#      1881     8
#      1882     9
#      1883    20
#      1884    12
#      1885    19
#      1886     7
#      1887     8
#      1888     9
#      1889     8
#      1890     6
#      1891    19
#      1892    10
#      1893    10
# ...

# %%
dates = pd.to_datetime([' '.join(item) for item in result.index])

# %%
days = dates.days_in_month

# %%
dates
# Out:
# DatetimeIndex(['1758-01-16', '1759-01-16', '1760-01-16', '1761-01-16',
#                '1762-01-16', '1763-01-16', '1764-01-16', '1765-01-16',
#                '1766-01-16', '1767-01-16',
#                ...
#                '1891-12-16', '1892-12-16', '1893-12-16', '1894-12-16',
#                '1895-12-16', '1896-12-16', '1897-12-16', '1898-12-16',
#                '1899-12-16', '1900-12-16'],
#               dtype='datetime64[ns]', length=1716, freq=None, tz=None)

# %%
result = (result / days).unstack()

# %%
result
# Out:
# Year      1758      1759      1760      1761      1762      1763      1764  \
# Jan   0.419355  0.354839  0.612903  0.451613  0.419355  0.258065  0.516129
# Feb   0.535714  0.357143  0.517241  0.571429  0.428571  0.678571  0.448276
# Mar   0.451613  0.225806  0.580645  0.451613  0.387097  0.387097  0.516129
# Apr   0.166667  0.133333  0.166667  0.300000  0.266667  0.133333  0.266667
# May   0.161290  0.096774  0.419355  0.290323  0.161290  0.354839  0.225806
# Jun   0.166667  0.200000  0.200000  0.366667  0.100000  0.333333  0.100000
# Jul   0.064516  0.354839  0.322581  0.322581  0.258065  0.225806  0.064516
# Aug   0.129032  0.161290  0.290323  0.322581  0.322581  0.387097  0.193548
# Sep   0.233333  0.366667  0.433333  0.400000  0.200000  0.533333  0.333333
# Oct   0.419355  0.483871  0.451613  0.451613  0.322581  0.516129  0.322581
# Nov   0.300000  0.333333  0.266667  0.500000  0.333333  0.533333  0.433333
# ...

# %%
df6 = result.transpose()

# %%
df6
# Out:
#            Jan       Feb       Mar       Apr       May       Jun       Jul  \
# Year
# 1758  0.419355  0.535714  0.451613  0.166667  0.161290  0.166667  0.064516
# 1759  0.354839  0.357143  0.225806  0.133333  0.096774  0.200000  0.354839
# 1760  0.612903  0.517241  0.580645  0.166667  0.419355  0.200000  0.322581
# 1761  0.451613  0.571429  0.451613  0.300000  0.290323  0.366667  0.322581
# 1762  0.419355  0.428571  0.387097  0.266667  0.161290  0.100000  0.258065
# 1763  0.258065  0.678571  0.387097  0.133333  0.354839  0.333333  0.225806
# 1764  0.516129  0.448276  0.516129  0.266667  0.225806  0.100000  0.064516
# 1765  0.419355  0.642857  0.290323  0.500000  0.258065  0.166667  0.129032
# 1766  0.419355  0.714286  0.548387  0.233333  0.161290  0.166667  0.225806
# 1767  0.419355  0.142857  0.290323  0.233333  0.129032  0.166667  0.258065
# 1768  0.483871  0.172414  0.322581  0.466667  0.161290  0.200000  0.258065
# ...

# %%
df7 = pd.rolling_mean(df6.stack(), window=12, center=True)

# %%
df7
# Out:
# Year
# 1758  Jan         NaN
#       Feb         NaN
#       Mar         NaN
#       Apr         NaN
#       May         NaN
#       Jun         NaN
#       Jul    0.283532
#       Aug    0.278155
#       Sep    0.263274
#       Oct    0.244457
#       Nov    0.241679
#       Dec    0.236303
# 1759  Jan    0.239081
#       Feb    0.263274
#       Mar    0.265963
#       Apr    0.277074
#       May    0.282450
#       Jun    0.285228
#       Jul    0.290604
#       Aug    0.312110
#       Sep    0.325451
#       Oct    0.355021
#       Nov    0.357799
#       Dec    0.384681
# 1760  Jan    0.384681
#       Feb    0.381992
#       Mar    0.392745
#       Apr    0.398301
#       May    0.395612
#       Jun    0.390057
#                ...
# 1898  Jul    0.357456
#       Aug    0.352080
#       Sep    0.325294
#       Oct    0.309165
#       Nov    0.314721
#       Dec    0.330850
# 1899  Jan    0.328072
#       Feb    0.341513
#       Mar    0.346889
#       Apr    0.338556
# ...

# %%
df7.unstack()
# Out:
#            Jan       Feb       Mar       Apr       May       Jun       Jul  \
# Year
# 1758       NaN       NaN       NaN       NaN       NaN       NaN  0.283532
# 1759  0.239081  0.263274  0.265963  0.277074  0.282450  0.285228  0.290604
# 1760  0.384681  0.381992  0.392745  0.398301  0.395612  0.390057  0.390057
# 1761  0.384626  0.384626  0.387314  0.384537  0.384537  0.403981  0.422798
# 1762  0.367076  0.361700  0.361700  0.345033  0.334281  0.320392  0.290822
# 1763  0.322677  0.319988  0.325365  0.353143  0.369272  0.385938  0.385938
# 1764  0.379919  0.366478  0.350349  0.333682  0.317553  0.309220  0.336102
# 1765  0.353123  0.358500  0.369252  0.383141  0.399270  0.404826  0.396761
# 1766  0.393932  0.401997  0.404685  0.396352  0.377535  0.358090  0.339273
# 1767  0.267460  0.270148  0.259396  0.273285  0.297478  0.328034  0.349539
# 1768  0.384977  0.384977  0.387665  0.362665  0.349224  0.321447  0.318758
# ...

# %%
df8 = df7.unstack().transpose()

# %%
df8
# Out:
# Year      1758      1759      1760      1761      1762      1763      1764  \
# Jan        NaN  0.239081  0.384681  0.384626  0.367076  0.322677  0.379919
# Feb        NaN  0.263274  0.381992  0.384626  0.361700  0.319988  0.366478
# Mar        NaN  0.265963  0.392745  0.387314  0.361700  0.325365  0.350349
# Apr        NaN  0.277074  0.398301  0.384537  0.345033  0.353143  0.333682
# May        NaN  0.282450  0.395612  0.384537  0.334281  0.369272  0.317553
# Jun        NaN  0.285228  0.390057  0.403981  0.320392  0.385938  0.309220
# Jul   0.283532  0.290604  0.390057  0.422798  0.290822  0.385938  0.336102
# Aug   0.278155  0.312110  0.376616  0.420110  0.277381  0.407444  0.328037
# Sep   0.263274  0.325451  0.381132  0.408205  0.298214  0.388252  0.344252
# Oct   0.244457  0.355021  0.370379  0.402829  0.298214  0.399005  0.325435
# Nov   0.241679  0.357799  0.381490  0.400051  0.287103  0.410116  0.344880
# ...

# %%
# %matplotlib inline

# %%
df8[['1770','1780','1790','1800']].plot()

# %%
df5[['1770','1780','1790','1800']].plot()

# %%
df7.unstack().to_excel('/Users/DMac/OneDrive/MasterThesis/data/LamMiron_detrended_births.xlsx')

# %%
df7*36500
# Out:
# Year
# 1758  Jan             NaN
#       Feb             NaN
#       Mar             NaN
#       Apr             NaN
#       May             NaN
#       Jun             NaN
#       Jul    10348.908730
#       Aug    10152.672171
#       Sep     9609.517409
#       Oct     8922.689452
#       Nov     8821.300563
#       Dec     8625.064004
# 1759  Jan     8726.452893
#       Feb     9609.517409
#       Mar     9707.635689
#       Apr    10113.191244
#       May    10309.427803
#       Jun    10410.816692
#       Jul    10607.053251
#       Aug    11391.999488
#       Sep    11878.965826
#       Oct    12958.266901
#       Nov    13059.655790
#       Dec    14040.838586
# 1760  Jan    14040.838586
#       Feb    13942.720307
#       Mar    14335.193425
#       Apr    14537.971203
#       May    14439.852923
#       Jun    14237.075145
#                  ...
# 1898  Jul    13047.161418
#       Aug    12850.924859
#       Sep    11873.246288
#       Oct    11284.536610
# ...

# %%
df5
# Out:
# Year  1758  1759  1760  1761  1762  1763  1764  1765  1766  1767  ...   1891  \
# Jan     13    11    19    14    13     8    16    13    13    13  ...      8
# Feb     15    10    15    16    12    19    13    18    20     4  ...      8
# Mar     14     7    18    14    12    12    16     9    17     9  ...      5
# Apr      5     4     5     9     8     4     8    15     7     7  ...      4
# May      5     3    13     9     5    11     7     8     5     4  ...      2
# Jun      5     6     6    11     3    10     3     5     5     5  ...      7
# Jul      2    11    10    10     8     7     2     4     7     8  ...      8
# Aug      4     5     9    10    10    12     6    10    11     7  ...      9
# Sep      7    11    13    12     6    16    10    15    12    17  ...     17
# Oct     13    15    14    14    10    16    10    16     9    18  ...     17
# Nov      9    10     8    15    10    16    13    15     8    19  ...     10
# ...

# %%
birth = df5.transpose()

# %%
birth
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 1758   13   15   14    5    5    5    2    4    7   13    9   11
# 1759   11   10    7    4    3    6   11    5   11   15   10   13
# 1760   19   15   18    5   13    6   10    9   13   14    8   13
# 1761   14   16   14    9    9   11   10   10   12   14   15   20
# 1762   13   12   12    8    5    3    8   10    6   10   10    9
# 1763    8   19   12    4   11   10    7   12   16   16   16    9
# 1764   16   13   16    8    7    3    2    6   10   10   13   19
# 1765   13   18    9   15    8    5    4   10   15   16   15   16
# 1766   13   20   17    7    5    5    7   11   12    9    8    9
# 1767   13    4    9    7    4    5    8    7   17   18   19   17
# 1768   15    5   10   14    5    6    8    8    8   13    9   16
# 1769   10   13   11    7    6    7    9   10    9   17   11   19
# 1770   12    8   17    9    4    9    9   14   15    9   13   22
# ...

# %%
moving_avg = pd.rolling_mean(birth.stack(), window=12, center=True)

# %%
moving_avg
# Out:
# Year
# 1758  Jan          NaN
#       Feb          NaN
#       Mar          NaN
#       Apr          NaN
#       May          NaN
#       Jun          NaN
#       Jul     8.583333
#       Aug     8.416667
#       Sep     8.000000
#       Oct     7.416667
#       Nov     7.333333
#       Dec     7.166667
# 1759  Jan     7.250000
#       Feb     8.000000
#       Mar     8.083333
#       Apr     8.416667
#       May     8.583333
#       Jun     8.666667
#       Jul     8.833333
#       Aug     9.500000
#       Sep     9.916667
#       Oct    10.833333
#       Nov    10.916667
#       Dec    11.750000
# 1760  Jan    11.750000
#       Feb    11.666667
#       Mar    12.000000
#       Apr    12.166667
#       May    12.083333
#       Jun    11.916667
#                ...
# 1898  Jul    10.833333
#       Aug    10.666667
#       Sep     9.916667
#       Oct     9.416667
#       Nov     9.583333
#       Dec    10.083333
# 1899  Jan    10.000000
#       Feb    10.416667
# ...

# %%
Ri = (birth/moving_avg) * 100

# %%
moving_avg = moving_avg.unstack()

# %%
moving_avg
# Out:
#             Jan        Feb        Mar        Apr        May        Jun  \
# Year
# 1758        NaN        NaN        NaN        NaN        NaN        NaN
# 1759   7.250000   8.000000   8.083333   8.416667   8.583333   8.666667
# 1760  11.750000  11.666667  12.000000  12.166667  12.083333  11.916667
# 1761  11.666667  11.666667  11.750000  11.666667  11.666667  12.250000
# 1762  11.166667  11.000000  11.000000  10.500000  10.166667   9.750000
# 1763   9.750000   9.666667   9.833333  10.666667  11.166667  11.666667
# 1764  11.583333  11.166667  10.666667  10.166667   9.666667   9.416667
# 1765  10.666667  10.833333  11.166667  11.583333  12.083333  12.250000
# 1766  11.916667  12.166667  12.250000  12.000000  11.416667  10.833333
# 1767   8.166667   8.250000   7.916667   8.333333   9.083333  10.000000
# 1768  11.750000  11.750000  11.833333  11.083333  10.666667   9.833333
# 1769   9.666667   9.750000   9.916667  10.000000  10.333333  10.500000
# ...

# %%
Ri

# %%
moving_avg_per_day = pd.rolling_mean(df6.stack(), window=12, center=True)
moving_avg_per_day = moving_avg_per_day.unstack()
moving_avg_per_day
# Out:
#            Jan       Feb       Mar       Apr       May       Jun       Jul  \
# Year
# 1758       NaN       NaN       NaN       NaN       NaN       NaN  0.283532
# 1759  0.239081  0.263274  0.265963  0.277074  0.282450  0.285228  0.290604
# 1760  0.384681  0.381992  0.392745  0.398301  0.395612  0.390057  0.390057
# 1761  0.384626  0.384626  0.387314  0.384537  0.384537  0.403981  0.422798
# 1762  0.367076  0.361700  0.361700  0.345033  0.334281  0.320392  0.290822
# 1763  0.322677  0.319988  0.325365  0.353143  0.369272  0.385938  0.385938
# 1764  0.379919  0.366478  0.350349  0.333682  0.317553  0.309220  0.336102
# 1765  0.353123  0.358500  0.369252  0.383141  0.399270  0.404826  0.396761
# 1766  0.393932  0.401997  0.404685  0.396352  0.377535  0.358090  0.339273
# 1767  0.267460  0.270148  0.259396  0.273285  0.297478  0.328034  0.349539
# 1768  0.384977  0.384977  0.387665  0.362665  0.349224  0.321447  0.318758
# ...

# %%
df6
bt = df6/moving_avg_per_day

# %%
bt
# Out:
#            Jan       Feb       Mar       Apr       May       Jun       Jul  \
# Year
# 1758       NaN       NaN       NaN       NaN       NaN       NaN  0.227545
# 1759  1.484178  1.356542  0.849016  0.481220  0.342624  0.701194  1.221038
# 1760  1.593279  1.354062  1.478428  0.418444  1.060014  0.512746  0.827009
# 1761  1.174160  1.485672  1.166011  0.780160  0.754993  0.907633  0.762966
# 1762  1.142419  1.184881  1.070215  0.772872  0.482500  0.312118  0.887363
# 1763  0.799762  2.120612  1.189731  0.377562  0.960915  0.863696  0.585084
# 1764  1.358524  1.223199  1.473185  0.799163  0.711082  0.323394  0.191954
# 1765  1.187559  1.793187  0.786244  1.305002  0.646340  0.411700  0.325214
# 1766  1.064535  1.776844  1.355096  0.588703  0.427220  0.465432  0.665560
# 1767  1.567914  0.528810  1.119226  0.853810  0.433754  0.508078  0.738299
# 1768  1.256882  0.447855  0.832111  1.286770  0.461853  0.622187  0.809593
# ...

# %%
lnbt = np.log(bt)
lnbt = lnbt.stack()
lnbt
# Out:
# Year
# 1758  Jul   -1.480409
#       Aug   -0.768118
#       Sep   -0.120729
#       Oct    0.539677
#       Nov    0.216170
#       Dec    0.406548
# 1759  Jan    0.394861
#       Feb    0.304939
#       Mar   -0.163678
#       Apr   -0.731431
#       May   -1.071121
#       Jun   -0.354971
#       Jul    0.199701
#       Aug   -0.660148
#       Sep    0.119241
#       Oct    0.309641
#       Nov   -0.070828
#       Dec    0.086304
# 1760  Jan    0.465794
#       Feb    0.303109
#       Mar    0.390979
#       Apr   -0.871211
#       May    0.058282
#       Jun   -0.667975
#       Jul   -0.189939
#       Aug   -0.260233
#       Sep    0.128363
#       Oct    0.198299
#       Nov   -0.358085
#       Dec    0.123224
#                ...
# 1898  Feb    0.365986
#       Mar    0.552568
#       Apr   -0.129847
#       May   -0.989183
#       Jun   -0.238936
#       Jul   -0.613486
#       Aug   -0.192866
#       Sep    0.024412
#       Oct    0.042477
#       Nov    0.393929
# ...

# %%
stacked_Ri = Ri.stack()

# %%
temp = pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/velkepole_T_1780_1860.csv', sep=",")
temp = temp.set_index('year')
temp = temp.stack()

# %%
temp.to_csv('/Users/DMac/OneDrive/MasterThesis/data/stacked_temperature.csv')

# %%
Ri.to_excel('/Users/DMac/OneDrive/MasterThesis/data/Ri.xlsx')
bt.to_excel('/Users/DMac/OneDrive/MasterThesis/data/bt.xlsx')
lnbt.to_csv('/Users/DMac/OneDrive/MasterThesis/data/lnbt_naturalLog.csv')
stacked_Ri.to_csv('/Users/DMac/OneDrive/MasterThesis/data/stacked_Ri.csv')
