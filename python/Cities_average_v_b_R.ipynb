# %%
import numpy as np 
import pandas as pd

# %%
viennaR=pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/HISTALP_AT_WIE_R01_1860_1900_Clean.csv', sep=",")

# %%
viennaR
# Out:
#     year  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  dec
# 0   1860   47   18   35   90   87   59   45   63   36   21   20   40
# 1   1861   48   25   46   25  122  131   48   42   11   11   26   24
# 2   1862   62   62   10   29  107   57   67   83   31   56   26   31
# 3   1863   18    8   35   56   44   35   40   31   63   16   41   56
# 4   1864    2   31   88   48   56  128   39   97   79   47   22   18
# 5   1865   30   37   48   12   53   81   88   71   18   49   24    5
# 6   1866   17   28   56   19   48   21   85  114   62   11   27   84
# 7   1867   70   45   36   71   97   61   60   16   43   60   29   79
# 8   1868   40   22   90   60  110   26   72   51   12   56   29   55
# 9   1869   11   46   41   33   34   26   43   71   18   42   96   52
# 10  1870   43   16   52   35   33   74  160   62   51   63   60   76
# 11  1871   30   16   46   40   44   48  138   59   55   50   41   26
# 12  1872   46   13   22   20   50   73   57  165   31   50   81   32
# ...

# %%
viennaR = viennaR.set_index('year')

# %%
viennaR
# Out:
#       jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  dec
# year
# 1860   47   18   35   90   87   59   45   63   36   21   20   40
# 1861   48   25   46   25  122  131   48   42   11   11   26   24
# 1862   62   62   10   29  107   57   67   83   31   56   26   31
# 1863   18    8   35   56   44   35   40   31   63   16   41   56
# 1864    2   31   88   48   56  128   39   97   79   47   22   18
# 1865   30   37   48   12   53   81   88   71   18   49   24    5
# 1866   17   28   56   19   48   21   85  114   62   11   27   84
# 1867   70   45   36   71   97   61   60   16   43   60   29   79
# 1868   40   22   90   60  110   26   72   51   12   56   29   55
# 1869   11   46   41   33   34   26   43   71   18   42   96   52
# 1870   43   16   52   35   33   74  160   62   51   63   60   76
# 1871   30   16   46   40   44   48  138   59   55   50   41   26
# 1872   46   13   22   20   50   73   57  165   31   50   81   32
# ...

# %%
budR=pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/HISTALP_HU_BUD_R01_1860_1900_Clean.csv', sep=",")

# %%
budR
# Out:
#     year  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  dec
# 0   1860   35   53   20   67   56   58   76   33   35   41   55   47
# 1   1861   24   19   41   29   50   66   12   28   20   18   53    7
# 2   1862   37   20   14   55  119   32   10   35   35    9   53   42
# 3   1863   38    2   31    1   35   14   22   29   40    7   49   29
# 4   1864    4   37   47   31   51   66   48   25   71   10   45   12
# 5   1865   42   24   74    0   18   46   22   40    2   38   24    6
# 6   1866   25   16  104   15   46   23   41   61   24   15   21   40
# 7   1867   62   27   40   96   42   82   47   49   37   70   29   77
# 8   1868   33   13   43   36   38   63   41   18   29   46   23   64
# 9   1869   16   20   39   29   24   27   39   28   34   44   58   81
# 10  1870   46   25    8   19   48   37   57  101   37   77   76   41
# 11  1871   48   12   31   31   17   69   11   43    9   47   91   24
# 12  1872   34   27   35   20   53   64   41   68   80   42   40   24
# ...

# %%
budR=budR.set_index('year')

# %%
budR
# Out:
#       jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  dec
# year
# 1860   35   53   20   67   56   58   76   33   35   41   55   47
# 1861   24   19   41   29   50   66   12   28   20   18   53    7
# 1862   37   20   14   55  119   32   10   35   35    9   53   42
# 1863   38    2   31    1   35   14   22   29   40    7   49   29
# 1864    4   37   47   31   51   66   48   25   71   10   45   12
# 1865   42   24   74    0   18   46   22   40    2   38   24    6
# 1866   25   16  104   15   46   23   41   61   24   15   21   40
# 1867   62   27   40   96   42   82   47   49   37   70   29   77
# 1868   33   13   43   36   38   63   41   18   29   46   23   64
# 1869   16   20   39   29   24   27   39   28   34   44   58   81
# 1870   46   25    8   19   48   37   57  101   37   77   76   41
# 1871   48   12   31   31   17   69   11   43    9   47   91   24
# 1872   34   27   35   20   53   64   41   68   80   42   40   24
# ...

# %%
cities_concatR = pd.concat((viennaR, budR))

# %%
by_row_index = cities_concatR.groupby(cities_concatR.index)

# %%
cities_means_R = by_row_index.mean()

# %%
cities_means_R
# Out:
#        jan   feb   mar    apr    may    jun    jul    aug    sep    oct  \
# year
# 1860  41.0  35.5  27.5   78.5   71.5   58.5   60.5   48.0   35.5   31.0
# 1861  36.0  22.0  43.5   27.0   86.0   98.5   30.0   35.0   15.5   14.5
# 1862  49.5  41.0  12.0   42.0  113.0   44.5   38.5   59.0   33.0   32.5
# 1863  28.0   5.0  33.0   28.5   39.5   24.5   31.0   30.0   51.5   11.5
# 1864   3.0  34.0  67.5   39.5   53.5   97.0   43.5   61.0   75.0   28.5
# 1865  36.0  30.5  61.0    6.0   35.5   63.5   55.0   55.5   10.0   43.5
# 1866  21.0  22.0  80.0   17.0   47.0   22.0   63.0   87.5   43.0   13.0
# 1867  66.0  36.0  38.0   83.5   69.5   71.5   53.5   32.5   40.0   65.0
# 1868  36.5  17.5  66.5   48.0   74.0   44.5   56.5   34.5   20.5   51.0
# 1869  13.5  33.0  40.0   31.0   29.0   26.5   41.0   49.5   26.0   43.0
# 1870  44.5  20.5  30.0   27.0   40.5   55.5  108.5   81.5   44.0   70.0
# 1871  39.0  14.0  38.5   35.5   30.5   58.5   74.5   51.0   32.0   48.5
# ...

# %%
cities_means_R.to_csv('/Users/DMac/OneDrive/MasterThesis/data/cities_means_R_v_b.csv', sep=";")
