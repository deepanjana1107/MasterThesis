# %%
import numpy as np 
import pandas as pd
# %matplotlib inline

# %%
two_cities_means=pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/cities_means_v_b.csv', sep=";")

# %%
kriging=pd.read_excel('/Users/DMac/OneDrive/VelkePole_T.xlsx')

# %%
kriging.head()
# Out:
#    year   jan   feb   mar    apr    may    jun    jul    aug    sep    oct  \
# 0  1860 -0.17 -1.37  1.96   9.85  15.66  18.46  17.44  18.93  15.72   7.92
# 1  1861 -5.48  2.70  4.75   7.64  11.79  19.49  20.42  21.20  16.51  10.44
# 2  1862 -3.80 -1.03  6.16  12.26  16.34  17.85  19.99  18.97  16.53  11.90
# 3  1863  1.47  1.52  6.52   9.05  16.46  18.48  19.67  21.88  17.10  12.21
# 4  1864 -8.09 -1.20  5.69   6.16  11.42  18.45  17.52  17.00  15.50   8.90
#
#     nov   dec
# 0  2.60 -1.39
# 1  3.69 -2.59
# 2  3.88 -1.70
# 3  5.02  0.81
# 4  3.10 -3.60

# %%
two_cities_means.head()
# Out:
#    year  jan   feb   mar    apr    may    jun    jul    aug    sep    oct  \
# 0  1860  0.8 -0.85  2.55  10.00  16.05  18.80  17.70  19.20  15.95   8.25
# 1  1861 -4.5  3.05  5.15   7.85  12.15  19.85  20.50  21.35  16.40  10.60
# 2  1862 -3.3 -0.80  6.60  12.75  16.60  18.10  20.65  19.15  16.65  11.85
# 3  1863  2.0  2.15  6.75   9.50  17.00  18.85  19.95  21.70  17.05  12.25
# 4  1864 -7.7 -0.50  6.10   6.85  12.15  18.70  18.20  17.35  15.50   8.60
#
#     nov   dec
# 0  2.60 -0.95
# 1  4.10 -2.50
# 2  4.10 -1.30
# 3  5.15  1.05
# 4  3.50 -3.40

# %%
two_cities_means=two_cities_means.set_index('year')

# %%
two_cities_means.head()
# Out:
#       jan   feb   mar    apr    may    jun    jul    aug    sep    oct   nov  \
# year
# 1860  0.8 -0.85  2.55  10.00  16.05  18.80  17.70  19.20  15.95   8.25  2.60
# 1861 -4.5  3.05  5.15   7.85  12.15  19.85  20.50  21.35  16.40  10.60  4.10
# 1862 -3.3 -0.80  6.60  12.75  16.60  18.10  20.65  19.15  16.65  11.85  4.10
# 1863  2.0  2.15  6.75   9.50  17.00  18.85  19.95  21.70  17.05  12.25  5.15
# 1864 -7.7 -0.50  6.10   6.85  12.15  18.70  18.20  17.35  15.50   8.60  3.50
#
#        dec
# year
# 1860 -0.95
# 1861 -2.50
# 1862 -1.30
# 1863  1.05
# 1864 -3.40

# %%
kriging=kriging.set_index('year')

# %%
kriging.head()
# Out:
#        jan   feb   mar    apr    may    jun    jul    aug    sep    oct   nov  \
# year
# 1860 -0.17 -1.37  1.96   9.85  15.66  18.46  17.44  18.93  15.72   7.92  2.60
# 1861 -5.48  2.70  4.75   7.64  11.79  19.49  20.42  21.20  16.51  10.44  3.69
# 1862 -3.80 -1.03  6.16  12.26  16.34  17.85  19.99  18.97  16.53  11.90  3.88
# 1863  1.47  1.52  6.52   9.05  16.46  18.48  19.67  21.88  17.10  12.21  5.02
# 1864 -8.09 -1.20  5.69   6.16  11.42  18.45  17.52  17.00  15.50   8.90  3.10
#
#        dec
# year
# 1860 -1.39
# 1861 -2.59
# 1862 -1.70
# 1863  0.81
# 1864 -3.60

# %%
diff = two_cities_means - kriging

# %%
diff.head()
# Out:
#        jan   feb   mar   apr   may   jun   jul   aug   sep   oct   nov   dec
# year
# 1860  0.97  0.52  0.59  0.15  0.39  0.34  0.26  0.27  0.23  0.33  0.00  0.44
# 1861  0.98  0.35  0.40  0.21  0.36  0.36  0.08  0.15 -0.11  0.16  0.41  0.09
# 1862  0.50  0.23  0.44  0.49  0.26  0.25  0.66  0.18  0.12 -0.05  0.22  0.40
# 1863  0.53  0.63  0.23  0.45  0.54  0.37  0.28 -0.18 -0.05  0.04  0.13  0.24
# 1864  0.39  0.70  0.41  0.69  0.73  0.25  0.68  0.35  0.00 -0.30  0.40  0.20

# %%
two_cities_means = two_cities_means.drop('jun-aug', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-f945d973605b> in <module>()
# ----> 1 two_cities_means = two_cities_means.drop('jun-aug', axis=1, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
two_cities_means = two_cities_means.drop('jun-aug', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f945d973605b> in <module>()
# ----> 1 two_cities_means = two_cities_means.drop('jun-aug', axis=1, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
two_cities_means

# %%
two_cities_means.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-acf96add3c7d> in <module>()
# ----> 1 two_cities_means.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
two_cities_means
# Out:
#        jan   feb   mar    apr    may    jun    jul    aug    sep    oct   nov  \
# year
# 1860  0.80 -0.85  2.55  10.00  16.05  18.80  17.70  19.20  15.95   8.25  2.60
# 1861 -4.50  3.05  5.15   7.85  12.15  19.85  20.50  21.35  16.40  10.60  4.10
# 1862 -3.30 -0.80  6.60  12.75  16.60  18.10  20.65  19.15  16.65  11.85  4.10
# 1863  2.00  2.15  6.75   9.50  17.00  18.85  19.95  21.70  17.05  12.25  5.15
# 1864 -7.70 -0.50  6.10   6.85  12.15  18.70  18.20  17.35  15.50   8.60  3.50
# 1865 -0.40 -4.20 -0.10  11.70  18.15  16.35  22.85  19.20  15.75  10.55  5.15
# 1866  0.10  3.10  5.40  12.30  12.50  21.20  19.75  17.55  17.65   7.85  4.15
# 1867 -0.40  3.70  2.75  10.35  14.95  18.00  19.00  20.35  16.30   9.10  2.10
# 1868 -1.55  2.70  4.25   9.60  18.20  20.35  20.75  20.40  17.70  12.00  3.30
# 1869 -2.75  4.20  3.40  12.65  18.15  16.70  22.15  18.70  16.45   8.00  4.35
# 1870 -1.50 -4.85  1.95   9.15  16.30  17.65  21.00  17.55  13.00   9.05  5.60
# ...

# %%
kriging
# Out:
#        jan    feb   mar    apr    may    jun    jul    aug    sep    oct  \
# year
# 1860 -0.17 -1.370  1.96   9.85  15.66  18.46  17.44  18.93  15.72   7.92
# 1861 -5.48  2.700  4.75   7.64  11.79  19.49  20.42  21.20  16.51  10.44
# 1862 -3.80 -1.030  6.16  12.26  16.34  17.85  19.99  18.97  16.53  11.90
# 1863  1.47  1.520  6.52   9.05  16.46  18.48  19.67  21.88  17.10  12.21
# 1864 -8.09 -1.200  5.69   6.16  11.42  18.45  17.52  17.00  15.50   8.90
# 1865 -1.03 -4.920 -0.74  10.78  17.73  15.88  22.66  18.87  15.39  10.55
# 1866 -0.56  3.000  4.79  11.98  12.02  20.90  19.50  17.36  17.75   7.48
# 1867 -1.48  3.230  2.30   9.88  14.50  17.33  18.50  20.06  15.98   9.27
# 1868 -2.26  2.380  3.91   9.08  17.95  19.98  20.46  20.02  17.55  11.78
# 1869 -3.60  4.000  2.92  12.15  17.73  16.18  21.67  18.42  16.17   7.59
# 1870 -1.96 -5.400  1.44   8.68  15.73  17.06  20.41  17.40  12.73   8.52
# 1871 -4.09 -2.040  4.30   8.94  11.40  15.55  20.55  20.14  15.79   7.47
# ...

# %%
diff.plot()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,12)
diff.ax(kind='bar')
ax.set_aspect(1)
plt.xlabel('Year')
plt.ylabel('Temperature Difference')
th=plt.title('Kriging versus Means')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-79c8bc306835> in <module>()
#       1 fig, ax = plt.subplots()
#       2 fig.set_size_inches(12,12)
# ----> 3 diff.ax(kind='bar')
#       4 ax.set_aspect(1)
#       5 plt.xlabel('Year')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ax'

# %%
import matplotlib.pyplot as plt

# %%
diff['1860'].plot(kind='bar', figsize=(20, 10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-961e7976cd1e> in <module>()
# ----> 1 diff['1860'].plot(kind='bar', figsize=(20, 10))
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
diff.plot(kind='barh', figsize=(20, 30), stacked=True, title="Kriging versus Two city average", color=tableau20)

# %%
diff_stack=diff.unset_index('year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-74e22c31dc72> in <module>()
# ----> 1 diff_stack=diff.unset_index('year')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unset_index'

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
matplotlib.style.available
# Out:
# [u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %%
matplotlib.style.use('dark_background')

# %%
three_cities_means=pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/cities_means_v_b_hp.csv', sep=";")

# %%
three_cities_means=three_cities_means.set_index('year')

# %%
diff1 = three_cities_means - kriging

# %%
diff1.plot(kind='barh', figsize=(12,30), stacked=True, title="Kriging versus Three city average", color=tableau20)

# %%
diff.head()
# Out:
#        jan   feb   mar   apr   may   jun   jul   aug   sep   oct   nov   dec
# year
# 1860  0.97  0.52  0.59  0.15  0.39  0.34  0.26  0.27  0.23  0.33  0.00  0.44
# 1861  0.98  0.35  0.40  0.21  0.36  0.36  0.08  0.15 -0.11  0.16  0.41  0.09
# 1862  0.50  0.23  0.44  0.49  0.26  0.25  0.66  0.18  0.12 -0.05  0.22  0.40
# 1863  0.53  0.63  0.23  0.45  0.54  0.37  0.28 -0.18 -0.05  0.04  0.13  0.24
# 1864  0.39  0.70  0.41  0.69  0.73  0.25  0.68  0.35  0.00 -0.30  0.40  0.20

# %%
diff1.head()
# Out:
#        jan   feb   mar   apr   may   jun   jul   aug   sep   oct   nov   dec
# year
# 1860  0.87 -1.33 -0.86 -1.92 -1.59 -1.76 -1.87 -1.63 -1.45 -0.42 -1.40  0.12
# 1861  0.78  0.13 -0.88 -1.34 -0.92 -1.72 -1.99 -1.40 -1.81 -0.31 -0.02  0.16
# 1862  0.70 -0.20  0.11 -1.09 -1.24 -1.95 -1.09 -1.57 -1.23 -0.77 -0.28  0.87
# 1863  0.23 -0.32 -1.65 -0.72 -1.49 -1.81 -1.84 -1.75 -2.10 -0.78 -0.69 -0.28
# 1864  1.16  0.20 -0.96 -0.73 -0.35 -2.08 -0.92 -1.20 -1.50 -1.40 -0.67 -0.03

# %%
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# %%
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
