# %%
import numpy as np 
import pandas as pd
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)] 

for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.) 
    
two_cities_means_R=pd.read_csv('/Users/DMac/OneDrive/MasterThesis/data/cities_means_R_v_b.csv', sep=";")

two_cities_means_R=two_cities_means_R.set_index('year')

kriging_R=pd.read_excel('/Users/DMac/OneDrive/MasterThesis/data/VelkePole_Kriging_R_Separated.xlsx', "withoutOP")

kriging_R=kriging_R.set_index('year')

diff_without_OP = two_cities_means_R - kriging_R

kriging_R_OP=pd.read_excel('/Users/DMac/OneDrive/MasterThesis/data/VelkePole_Kriging_R_Separated.xlsx', "withOP")

kriging_R_OP=kriging_R_OP.set_index('year')

diff_with_OP = two_cities_means_R - kriging_R_OP

kriging_R_diff = kriging_R - kriging_R_OP

kriging_OP_kriging_R_diff = kriging_R_OP - kriging_R

# %%
diff_without_OP
# Out:
#         jan     feb    mar    apr    may    jun    jul    aug    sep    oct  \
# year
# 1860   5.43  -3.720   1.99   8.27  10.45 -10.54  -2.12  -8.54   2.24  -8.17
# 1861  -3.37   7.870  -2.50   3.83  -5.00  -6.92  -4.02  -8.47  -0.49   1.75
# 1862  -4.72   0.400  -5.17  -1.40  -0.33 -22.13   9.53   0.02   8.42  12.43
# 1863  -4.83  -6.160  -7.48  -1.80   6.95  10.48  -6.15   2.30   0.23  -3.74
# 1864  -2.70   0.990   6.23  -3.45   1.95  12.47  -2.88  -1.16   9.24  -1.55
# 1865  -7.04  -0.120   5.02   0.84  -7.75  10.50   6.51 -25.78   0.50   1.10
# 1866  -1.23 -13.020   7.87  -2.07 -11.00  -1.72   8.39 -16.17  -3.68   3.63
# 1867   4.71   4.530  -2.84  12.80   3.13   0.90  -4.57  -3.23   0.29  -1.46
# 1868   3.83  -5.260  10.67 -12.17  23.17  -2.66   3.55   3.27   3.54   6.60
# 1869  -2.00  -2.330   7.57  -1.38   1.60 -11.16 -12.24   1.06   1.80   1.83
# 1870   3.37   3.140   3.55   3.57   1.86   1.64  14.83 -15.44   3.07  -5.00
# ...

# %%
diff_with_OP
# Out:
#         jan    feb    mar    apr    may    jun    jul    aug    sep    oct  \
# year
# 1860   5.43  -3.72   1.99   8.27  10.45 -10.54  -2.12  -8.54   2.24  -8.17
# 1861  -3.37   7.87  -2.50   3.83  -5.00  -6.92  -4.02  -8.47  -0.49   1.75
# 1862  -4.72   0.40  -5.17  -1.40  -0.33 -22.13   9.53   0.02   8.42  12.43
# 1863  -4.83  -6.16  -7.48  -1.80   6.95  10.48  -6.15   2.30   0.23  -3.74
# 1864  -2.70   0.99   6.23  -3.45   1.95  12.47  -2.88  -1.16   9.24  -1.55
# 1865  -7.04  -0.12   5.02   0.84  -7.75  10.50   6.51 -25.78   0.50   1.10
# 1866  -1.23 -13.02   7.87  -2.07 -11.00  -1.72   8.39 -16.17  -3.68   3.63
# 1867   4.71   4.53  -2.84  12.80   3.13   0.90  -4.57  -3.23   0.29  -1.46
# 1868   3.83  -5.26  10.67 -12.17  23.17  -2.66   3.55   3.27   3.54   6.60
# 1869  -2.00  -2.33   7.57  -1.38   1.60 -11.16 -12.24   1.06   1.80   1.83
# 1870   3.37   3.14   3.55   3.57   1.86   1.64  14.83 -15.44   3.07  -5.00
# ...

# %%
diff_without_OP.to_excel('/Users/DMac/OneDrive/MasterThesis/data/means-kriging-diff_R_withoutOP.xlsx', sheet_name='Sheet1')

# %%
diff_with_OP.to_excel('/Users/DMac/OneDrive/MasterThesis/data/means-kriging-diff_R_withOP.xlsx', sheet_name='Sheet1')

kriging_R_diff.to_excel('/Users/DMac/OneDrive/MasterThesis/data/kriging-kriging_OP_R-diff.xlsx', sheet_name='Sheet1')

kriging_OP_kriging_R_diff.to_excel('/Users/DMac/OneDrive/MasterThesis/data/kriging_OP-kriging_R-diff.xlsx', sheet_name='Sheet1')

# %%
diff_without_OP.plot(kind='barh', figsize=(20, 30), stacked=True, title="Kriging versus Two city Mean R without OP", color=tableau20)

# %%
diff_with_OP.plot(kind='barh', figsize=(20, 30), stacked=True, title="Kriging versus Two city Mean R with OP", color=tableau20)
